# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Google Colab wants to use newer Keras 2, Tensorflow 2 but this
# notebook was written against older version.
# %tensorflow_version 1.x
# !pip install keras==1.2
# !pip install fuel
# !pip install picklable_itertools

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/Dr Eglash/Kente_Cloth_Authentication/oc-nn/"
#PROJECT_DIR = "/content/drive/My Drive/2019/testing/oc-nn/"
# PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
IMG_DIM= 784

sys.path.append(PROJECT_DIR)
import platform
print("Using Python: ", platform.python_version())
import keras
print("Using Keras: ", keras.__version__)
# Out:
# 3.6.9
# Using Keras:  1.2.0

# %% [markdown]
# # **  One Class Deep SVDD _9  Vs All-  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

print(sys.path)


from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "mnist"
IMG_DIM= 784
IMG_HGT =28
IMG_WDT=28
IMG_CHANNEL=1
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/MNIST/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/MNIST/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  DIGITs  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")

# %% [markdown]
# # **  One Class Deep SVDD _8  Vs All-  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "mnist"
IMG_DIM= 784
IMG_HGT =28
IMG_WDT=28
IMG_CHANNEL=1
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/MNIST/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/MNIST/OC_NN/"
PRETRAINED_WT_PATH = ""
# LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
  
  print("[INFO:] Testing with ALL other  DIGITs  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.+.+.+...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.7779272091240852
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03045072737065635
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03045072737065635
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9107043913940466
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++++.++.++.+...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.3492744106945782
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.030207667993076864
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.030207667993076864
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.912071912761568
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++.++.++.+...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.6814070286901153
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03115107402371231
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03115107402371231
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9332832301797819
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.+.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.6505683128164392
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.04115397662525333
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.04115397662525333
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9073710580607133
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++++......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.3160736608039763
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.033398832607156814
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.033398832607156814
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9129767167698202
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.+.+....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.762652522702787
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.032022336903156756
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.032022336903156756
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.8889507810197466
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.+++.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.764062786412886
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.026483714208764164
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.026483714208764164
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.8775331564986737
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++.++.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.0991885724826638
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.032324204076797924
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.032324204076797924
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9202033598585322
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.+.+.+...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.1672047198695417
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.0282107249467628
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.0282107249467628
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.7767256115531977
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4926, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++++......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4926, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.1829130979651552
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03082871374056717
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5908, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5850, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03082871374056717
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.8149012673150604
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.9107043913940466, 0.912071912761568, 0.9332832301797819, 0.9073710580607133, 0.9129767167698202, 0.8889507810197466, 0.8775331564986737, 0.9202033598585322, 0.7767256115531977, 0.8149012673150604]
# AUROC ===== 0.885472148541114 +/- 0.047909937045523356
# ========================================================================

# %% [markdown]
# # ** One Class  Deep SVDD _7  Vs All-  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "mnist"
IMG_DIM= 784
IMG_HGT =28
IMG_WDT=28
IMG_CHANNEL=1
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/MNIST/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/MNIST/OC_NN/"
PRETRAINED_WT_PATH = ""
# LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
  
  print("[INFO:] Testing with ALL other  DIGITs  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b55c218c35eb> in <module>()
#       2 get_ipython().magic('autoreload 2')
#       3
# ----> 4 from src.models.OneClass_SVDD import OneClass_SVDD
#       5 from src.models.config import Configuration as Cfg
#       6
#
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/models/OneClass_SVDD.py in <module>()
#       3 # import the necessary packages
#       4 import numpy as np
# ----> 5 from src.data.preprocessing import learn_dictionary, global_contrast_normalization
#       6 from sklearn.metrics import average_precision_score, mean_squared_error
#       7 from sklearn.metrics import roc_auc_score
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# # **  One Class  Deep SVDD _6  Vs All-  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "mnist"
IMG_DIM= 784
IMG_HGT =28
IMG_WDT=28
IMG_CHANNEL=1
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/MNIST/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/MNIST/OC_NN/"
PRETRAINED_WT_PATH = ""
# LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
  
  print("[INFO:] Testing with ALL other  DIGITs  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4982, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.++.+.+.+.+.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.7898930343634465
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.029854639227203134
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.029854639227203134
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9562525613254493
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4982, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++++++.+++++.++++.+++.+...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.6506221475047376
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03203168520105981
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03203168520105981
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9512177272993385
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4982, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++++.++.+....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.939364188748181
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03586759892671121
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03586759892671121
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9767958550436158
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4982, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++.++.++.++.++.+.+................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4982, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.6166304944334833
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03398961365877251
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (58, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03398961365877251
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9854721620514022
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5948, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5890, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (58, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4982, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9984354213534048
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++++++.+++++++.++.+...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.5162062680430495
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.036127589725836184
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.036127589725836184
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9962454532195405
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.+.+.+.+.+.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.453929913266876
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03465896131213331
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03465896131213331
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9957239270040087
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.+++.+++.+.+.+.+.+.+.+.............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 3.223253297151544
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03472407182186399
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03472407182186399
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9955427187426799
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++++.++++++.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.264744281904484
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03131194796080017
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03131194796080017
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9950322418113755
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.++.+.+.+.+.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.9714093277851674
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03239259505750436
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03239259505750436
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9947383308509274
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++++.+.+.+.+.+.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.9207537196661377
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03473340729599794
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03473340729599794
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9928997299554935
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (67, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (5677, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++++......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (5677, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.1973714982203205
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03067192072522007
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6821, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6754, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (67, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03067192072522007
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9948267251247465
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.9936378221418817, 0.9965703021758251, 0.9984354213534048, 0.9962454532195405, 0.9957239270040087, 0.9955427187426799, 0.9950322418113755, 0.9947383308509274, 0.9928997299554935, 0.9948267251247465]
# AUROC ===== 0.9953652672379883 +/- 0.0014720642699141105
# ========================================================================

# %% [markdown]
# # **  One Class  Deep SVDD _0  Vs All-  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "mnist"
IMG_DIM= 784
IMG_HGT =28
IMG_WDT=28
IMG_CHANNEL=1
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/MNIST/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/MNIST/OC_NN/"
PRETRAINED_WT_PATH = ""
# LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  DIGITs  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-69034403f7cf>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.2301597164263782
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.02968245906056527
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.02968245906056527
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9293985858516406
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++++.+++++.+++.+++.+++.+++..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.577943993786306
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.034069611904960606
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.034069611904960606
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9947542430180722
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.++.+....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.254030915357667
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03269679397914982
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03269679397914982
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9823202805376973
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++++.++++.+++.++.+..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.467321801950753
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.02960289021871959
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.02960289021871959
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9776847618065344
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++++.++++.+.+.+.+.+................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.0852643522607366
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.033540574574835946
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.033540574574835946
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9655487560307583
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.+.+.+.+..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.2219126763286354
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03456955111128379
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03456955111128379
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9909409701928696
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.++.++.++.++.++.++.++.+.+.............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 1.9283323985699496
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.028920403212572943
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.028920403212572943
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9914595294576042
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.++++.++.++.++.+.+.+.+.+.+.+.+.+..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 3.02674351077259
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03682492174552743
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03682492174552743
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9794782319707543
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++++.++.++.++.+.+.+.+.+.+.............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.4015469591624097
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.03483845353081483
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.03483845353081483
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9794094727312317
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Testing with ALL other  DIGITs  as anomalies
# [INFO: ] Shape of One Class Input Data used in training (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in training (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in training (59, 28, 28, 1)
# [ INFO ] : The shape of Xtrain is  (4986, 28, 28, 1)
# Learning dictionary for weight initialization...
# [dict_learning] .+++++++.+++.++.++.++.++.+.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Dictionary learned.
# [INFO:] The shape of X used to train CAE (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_train (4986, 28, 28, 1)
# [INFO:] The shape of self.data._X_test (10000, 28, 28, 1)
# INFO: Autoencoder training completed for mnist....
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 2.258455280054875
# [INFO:] Hyperplane Loss function.....
# [INFO:]
#  Model compiled  Outside CB: Updated Radius Value... 0.026683375111448804
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (5975, 28, 28, 1)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (5916, 28, 28, 1)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (59, 28, 28, 1)
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Saving Anomalies Found at .. /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/OC_NN/
# [INFO:] Final Rvar used is  0.026683375111448804
# [INFO:] One Class Neural Network Algorithm
# ===================================
# [INFO:]  AUROC: Oneclass Neural Network (OCNN) .... 0.9696714454338135
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.9293985858516406, 0.9947542430180722, 0.9823202805376973, 0.9776847618065344, 0.9655487560307583, 0.9909409701928696, 0.9914595294576042, 0.9794782319707543, 0.9794094727312317, 0.9696714454338135]
# AUROC ===== 0.9760666277030976 +/- 0.017892413907641215
# ========================================================================
